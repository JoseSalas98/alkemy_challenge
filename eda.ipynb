# %% [markdown]
# <div id='id1' > </div>
#
# <head>
#      <meta http-equiv="Content-Type"content="text/html"charset="utf-8">
#      <title>VIAJES ALEGRES</title>
#      <link href="./css_estilos/estilo_01.css"rel="stylesheet"type="text/css">
# </head>
# <body>
#      <img src="./css_estilos/JSLogoFondoClaro.png" style="float: right" width="250" height="230">
#      <h1> <b> Generalidades: </b> <br> Análisis Exploratorio de Datos</h1>
#      <p> Los archivos fuentes utilizados en el proyecto fueron recuperados de la web, almacenados localmente, y transformados para obtener información relevante, tal como: <p>
#      <ul>
#           <li> <b> <p>
#           Cantidad de registros totales por categoría
#           </b>. </p> </li>
#           <li> <b> <p>
#           Cantidad de registros por provincia y categoría
#           </b>. </p> </li>
#           <li> <b> <p>
#           Cantidad de registros totales por fuente de datos
#           </b>. </p> </li>
#           <li> <b> <p>
#           Cantidad de pantallas, butacas, espacios INCAA por provincia, a partir de la fuente de datos: Salas de Cines
#           </b>. </p> </li>
#      </ul>
# </body>

# %% [markdown]
# ---

# %% [markdown]
# <div id='id0' > </div>
#
#
# <head>
#     <meta http-equiv="Content-Type"content="text/html"charset="utf-8">
#     <title>VIAJES ALEGRES</title>
#     <link href="./css_estilos/estilo_01.css"rel="stylesheet"type="text/css">
# </head>
# <body>
#     <h1> <b> Índice </b> </h1>
# </body>
#
# 1.  [<p style="font-family: rubik"> Generalidades </p>](#id1)
# 2.  [<p style="font-family: rubik"> Características Preliminares de las Fuentes de Datos </p>](#id2)
# 3.  [<p style="font-family: rubik"> Imoportación de la Librerías Requeridas </p>](#id3)
# 4.  [<p style="font-family: rubik"> Extración de los Datos </p>](#id4)
# 5.  [<p style="font-family: rubik"> Carga de los Datos en Dataframes </p>](#id5)
# 6.  [<p style="font-family: rubik"> Fuente de Datos: Bibliotecas Populares </p>](#id6)
# 7.  [<p style="font-family: rubik"> Fuente de Datos: Museos </p>](#id7)
# 8.  [<p style="font-family: rubik"> Fuente de Datos: Salas de Cines </p>](#id8)
# 9.  [<p style="font-family: rubik"> Unión de los Dataframes </p>](#id9)
# 10. [<p style="font-family: rubik"> Obtención de los Insights </p>](#id10)
#
# ---

# %% [markdown]
# <div id='id2' > </div>
#
# <head>
#      <meta http-equiv="Content-Type"content="text/html"charset="utf-8">
#      <title>VIAJES ALEGRES</title>
#      <link href="./css_estilos/estilo_01.css"rel="stylesheet"type="text/css">
# </head>
# <body>
#      <h1> <b> Características Preliminares de las Fuentes de Datos </b> <br> </h1>
#      <p>
#      Los datasets disponibles corresponden ha datos públicos generados, guardados y publicados por organismos de gobierno de la República Argentina, pertenecen a la categoría de bases georreferenciadas de Espacios Culturales. Se incluyen a aquellos espacios físicos, con diverso grado de formalidad e institucionalización, en donde se realizan con asiduidad y continuidad actividades culturales de diversa índole. <br>
#      <br>
#      Los recursos recuperados de las fuentes fueron:
#           <ul>
#                <li> <b> <p>
#                Bibliotecas Especializadas
#                </b>. </p> </li>
#                <li> <b> <p>
#                Museo
#                </b>. </p> </li>
#                <li> <b> <p>
#                Salas de Cine
#                </b>. </p> </li>
#                </ul>
#      </p>
# </body>

# %% [markdown]
# [<p style="font-family: rubik"> Índice </p> ](#id0)
#
# ---

# %% [markdown]
# <div id='id3' > </div>
#
# <head>
#      <meta http-equiv="Content-Type"content="text/html"charset="utf-8">
#      <title>VIAJES ALEGRES</title>
#      <link href="./css_estilos/estilo_01.css"rel="stylesheet"type="text/css">
# </head>
# <body>
#      <h1> <b> Imoportación de la Librerías Requeridas </b> <br> </h1>
# </body>

# %%
#   Importamos la librerías
import requests
from datetime import datetime
from pathlib import Path
import pandas as pd

# %% [markdown]
# [<p style="font-family: rubik"> Índice </p> ](#id0)
#
# ---

# %% [markdown]
# <div id='id4' > </div>
#
# <head>
#      <meta http-equiv="Content-Type"content="text/html"charset="utf-8">
#      <title>VIAJES ALEGRES</title>
#      <link href="./css_estilos/estilo_01.css"rel="stylesheet"type="text/css">
# </head>
# <body>
#      <h1> <b> Extración de los Datos </b> <br> </h1>
# </body>

# %%
#   Definimos los directorios y las rutas
main_dir = Path('./dataset')
data_path = "{category}/{year}-{month:02d}/{category}-{day:02d}-{month:02d}-{year}.csv"

# %%
#   Creamos una lista de diccionarios para almacenar la categoría y la url
category_list = [
    {
        "name": "museo",
        "url": "https://datos.cultura.gob.ar/dataset/37305de4-3cce-4d4b-9d9a-fec3ca61d09f/resource/4207def0-2ff7-41d5-9095-d42ae8207a5d/download/museos_datosabiertos.csv"

    },
    {
        "name": "sala_cine",
        "url": "https://datos.cultura.gob.ar/dataset/37305de4-3cce-4d4b-9d9a-fec3ca61d09f/resource/392ce1a8-ef11-4776-b280-6f1c7fae16ae/download/cine.csv"
    },
    {
        "name": "biblioteca_popular",
        "url": "https://datos.cultura.gob.ar/dataset/37305de4-3cce-4d4b-9d9a-fec3ca61d09f/resource/01c6c048-dbeb-44e0-8efa-6944f73715d7/download/biblioteca_popular.csv"
    }
    ]

# %%
def get_scrap(category_list):
    for i in range(len(category_list)):
        now = datetime.now()
        category = category_list[i]["name"]
        year = now.year
        month = now.month
        day = now.day
        
        r = requests.get(category_list[i]["url"])
        r.encoding = 'utf-8'
        fl_path = data_path.format(category = category, year = year, 
                                    month = month, day = day)

        main_path = main_dir/fl_path
        main_path.parent.mkdir(parents=True,exist_ok=True)

        with open(main_path,'w') as file_outp:
            file_outp.write(r.text)
            file_name = "{category}-{day:02d}-{month:02d}-{year}.csv".format(category = category, 
                                                                            year = year, 
                                                                            month = month, 
                                                                            day = day)
            print(f"Se ha guardado el archivo: {file_name} \nEn el directorio: {main_path} \n")

# %%
get_scrap(category_list = category_list)
# Out:
# Se ha guardado el archivo: museo-20-07-2022.csv
# En el directorio: dataset/museo/2022-07/museo-20-07-2022.csv
#
# Se ha guardado el archivo: sala_cine-20-07-2022.csv
# En el directorio: dataset/sala_cine/2022-07/sala_cine-20-07-2022.csv
#
# Se ha guardado el archivo: biblioteca_popular-20-07-2022.csv
# En el directorio: dataset/biblioteca_popular/2022-07/biblioteca_popular-20-07-2022.csv

# %% [markdown]
# [<p style="font-family: rubik"> Índice </p> ](#id0)
#
# ---

# %% [markdown]
# <div id='id5' > </div>
#
# <head>
#      <meta http-equiv="Content-Type"content="text/html"charset="utf-8">
#      <title>VIAJES ALEGRES</title>
#      <link href="./css_estilos/estilo_01.css"rel="stylesheet"type="text/css">
# </head>
# <body>
#      <h1> <b> Carga de los Datos en Dataframes </b> <br> </h1>
# </body>

# %% [markdown]
# <div id='id6' > </div>
#
# <head>
#      <meta http-equiv="Content-Type"content="text/html"charset="utf-8">
#      <title>VIAJES ALEGRES</title>
#      <link href="./css_estilos/estilo_01.css"rel="stylesheet"type="text/css">
# </head>
# <body>
#      <h2> <b> Fuente de Datos</b>: Bibliotecas Populares </h2>
# </body>

# %%
#   Declaramos los parámetros para la carga del dataframe
path = "./dataset/biblioteca_popular/2022-07/biblioteca_popular-20-07-2022.csv"
sep = ","
cod = "utf-8"

library_df = pd.read_csv(filepath_or_buffer = path, delimiter = sep, encoding = cod)

# %%
#   Visualizamos preliminarmente el dataframe
library_df.head()
# Out:
#     Cod_Loc  IdProvincia  IdDepartamento  Observacion              Categoría  \
# 0  70049060           70           70049          NaN  Bibliotecas Populares
# 1   2000010            2            2000          NaN  Bibliotecas Populares
# 2   2000010            2            2000          NaN  Bibliotecas Populares
# 3   2000010            2            2000          NaN  Bibliotecas Populares
# 4   2000010            2            2000          NaN  Bibliotecas Populares
#
#    Subcategoria                        Provincia  \
# 0           NaN                         San Juan
# 1           NaN  Ciudad Autónoma de Buenos Aires
# 2           NaN  Ciudad Autónoma de Buenos Aires
# 3           NaN  Ciudad Autónoma de Buenos Aires
# 4           NaN  Ciudad Autónoma de Buenos Aires
#
#                       Departamento               Localidad  \
# 0                          Iglesia                   Rodeo
# 1  Ciudad Autonoma de Buenos Aires  Ciudad de Buenos Aires
# ...

# %% [markdown]
# <head>
#      <meta http-equiv="Content-Type"content="text/html"charset="utf-8">
#      <title>VIAJES ALEGRES</title>
#      <link href="./css_estilos/estilo_01.css"rel="stylesheet"type="text/css">
# </head>
# <body>
#      <h3> <b> Identificación de los Tipos de Datos </b> </h3>
# </body>

# %%
#   Visualizamos las columnas del dataframe y sus tipos de datos
library_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2017 entries, 0 to 2016
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Cod_Loc                2017 non-null   int64
#  1   IdProvincia            2017 non-null   int64
#  2   IdDepartamento         2017 non-null   int64
#  3   Observacion            0 non-null      float64
#  4   Categoría              2017 non-null   object
#  5   Subcategoria           0 non-null      float64
#  6   Provincia              2017 non-null   object
#  7   Departamento           2017 non-null   object
#  8   Localidad              2017 non-null   object
#  9   Nombre                 2017 non-null   object
#  10  Domicilio              2017 non-null   object
#  11  Piso                   0 non-null      float64
#  12  CP                     2017 non-null   object
#  13  Cod_tel                2017 non-null   object
# ...

# %% [markdown]
# <head>
#      <meta http-equiv="Content-Type"content="text/html"charset="utf-8">
#      <title>VIAJES ALEGRES</title>
#      <link href="./css_estilos/estilo_01.css"rel="stylesheet"type="text/css">
# </head>
# <body>
#      <h3> <b> Selección de las Columnas de Interes </b> </h3>
# </body>

# %%
#   Definimos las columnas que deseamos conservar
columns = [ 
            "Cod_Loc", 
            "IdProvincia", 
            "IdDepartamento", 
            "Categoría", 
            "Provincia", 
            "Localidad", 
            "Nombre", 
            "Domicilio", 
            "CP",
            "Teléfono", 
            "Mail", 
            "Web"
            ]

# %%
#   Duplicamos el dataframe original conservando únicamente las columnas de interes
library_edit_df = library_df[columns]

# %% [markdown]
# <head>
#      <meta http-equiv="Content-Type"content="text/html"charset="utf-8">
#      <title>VIAJES ALEGRES</title>
#      <link href="./css_estilos/estilo_01.css"rel="stylesheet"type="text/css">
# </head>
# <body>
#      <h3> <b> Renombrado de las Columnas </b> </h3>
# </body>

# %%
#   Definimos la nueva denominación que tendrán las columnas de interes
renamed_columns = {
                    "Cod_Loc":"cod_localidad",
                    "IdProvincia":"id_provincia",
                    "IdDepartamento":"id_departamento",
                    "Categoría":"categoria",
                    "Provincia":"provincia",
                    "Localidad":"localidad",
                    "Nombre":"nombre",
                    "Domicilio":"domicilio",
                    "CP":"codigo_postal",
                    "Teléfono":"numero_de_telefono",
                    "Mail":"mail",
                    "Web":"web"
                    }

# %%
#   Renombramos el dataframe
library_edit_df.rename(columns = renamed_columns, inplace = True)
# Out:
# /tmp/ipykernel_37097/405430763.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   library_edit_df.rename(columns = renamed_columns, inplace = True)

# %%
#   Comprobamos que el dataframe haya sido actualizado con los cambios indicados
library_edit_df.head()
# Out:
#    cod_localidad  id_provincia  id_departamento              categoria  \
# 0       70049060            70            70049  Bibliotecas Populares
# 1        2000010             2             2000  Bibliotecas Populares
# 2        2000010             2             2000  Bibliotecas Populares
# 3        2000010             2             2000  Bibliotecas Populares
# 4        2000010             2             2000  Bibliotecas Populares
#
#                          provincia               localidad  \
# 0                         San Juan                   Rodeo
# 1  Ciudad Autónoma de Buenos Aires  Ciudad de Buenos Aires
# 2  Ciudad Autónoma de Buenos Aires  Ciudad de Buenos Aires
# 3  Ciudad Autónoma de Buenos Aires  Ciudad de Buenos Aires
# 4  Ciudad Autónoma de Buenos Aires  Ciudad de Buenos Aires
#
#                                         nombre             domicilio  \
# 0         Biblioteca Popular Juan P. Garramuno         Santo Domingo
# ...

# %% [markdown]
# [<p style="font-family: rubik"> Índice </p> ](#id0)
#
# ---

# %% [markdown]
# <div id='id7' > </div>
#
# <head>
#      <meta http-equiv="Content-Type"content="text/html"charset="utf-8">
#      <title>VIAJES ALEGRES</title>
#      <link href="./css_estilos/estilo_01.css"rel="stylesheet"type="text/css">
# </head>
# <body>
#      <h2> <b> Fuente de Datos</b>: Museos </h2>
# </body>

# %%
#   Declaramos los parámetros para la carga del dataframe
path = "./dataset/museo/2022-07/museo-20-07-2022.csv"
sep = ","
cod = "utf-8"

museum_df = pd.read_csv(filepath_or_buffer = path, delimiter = sep, encoding = cod)

# %%
#   Visualizamos preliminarmente el dataframe
museum_df.head()
# Out:
#    Cod_Loc  IdProvincia  IdDepartamento  Observaciones  \
# 0  6588100            6            6588            NaN
# 1  6077010            6            6077            NaN
# 2  6035010            6            6035            NaN
# 3  6035010            6            6035            NaN
# 4  6049020            6            6049            NaN
#
#                             categoria subcategoria     provincia   localidad  \
# 0  Espacios de Exhibición Patrimonial       Museos  Buenos Aires  9 de Julio
# 1  Espacios de Exhibición Patrimonial       Museos  Buenos Aires   Arrecifes
# 2  Espacios de Exhibición Patrimonial       Museos  Buenos Aires  Avellaneda
# 3  Espacios de Exhibición Patrimonial       Museos  Buenos Aires  Avellaneda
# 4  Espacios de Exhibición Patrimonial       Museos  Buenos Aires        Azul
#
#                                               nombre  \
# 0     Archivo Y Museo Histórico Gral. Julio De Vedia
# 1             Museo Y Archivo Histórico De Arrecifes
# ...

# %% [markdown]
# <head>
#      <meta http-equiv="Content-Type"content="text/html"charset="utf-8">
#      <title>VIAJES ALEGRES</title>
#      <link href="./css_estilos/estilo_01.css"rel="stylesheet"type="text/css">
# </head>
# <body>
#      <h3> <b> Identificación de los Tipos de Datos </b> </h3>
# </body>

# %%
#   Visualizamos las columnas del dataframe y sus tipos de datos
museum_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1182 entries, 0 to 1181
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Cod_Loc              1182 non-null   int64
#  1   IdProvincia          1182 non-null   int64
#  2   IdDepartamento       1182 non-null   int64
#  3   Observaciones        0 non-null      float64
#  4   categoria            1182 non-null   object
#  5   subcategoria         1049 non-null   object
#  6   provincia            1182 non-null   object
#  7   localidad            1182 non-null   object
#  8   nombre               1182 non-null   object
#  9   direccion            1164 non-null   object
#  10  piso                 0 non-null      float64
#  11  CP                   1116 non-null   object
#  12  cod_area             989 non-null    float64
#  13  telefono             988 non-null    object
#  14  Mail                 264 non-null    object
# ...

# %% [markdown]
# <head>
#      <meta http-equiv="Content-Type"content="text/html"charset="utf-8">
#      <title>VIAJES ALEGRES</title>
#      <link href="./css_estilos/estilo_01.css"rel="stylesheet"type="text/css">
# </head>
# <body>
#      <h3> <b> Selección de las Columnas de Interes </b> </h3>
# </body>

# %%
#   Definimos las columnas que deseamos conservar
columns = [ 
            "Cod_Loc", 
            "IdProvincia", 
            "IdDepartamento", 
            "categoria", 
            "provincia", 
            "localidad", 
            "nombre", 
            "direccion", 
            "CP",
            "telefono", 
            "Mail", 
            "Web"
            ]

# %%
#   Duplicamos el dataframe original conservando únicamente las columnas de interes
museum_edit_df = museum_df[columns]

# %% [markdown]
# <head>
#      <meta http-equiv="Content-Type"content="text/html"charset="utf-8">
#      <title>VIAJES ALEGRES</title>
#      <link href="./css_estilos/estilo_01.css"rel="stylesheet"type="text/css">
# </head>
# <body>
#      <h3> <b> Renombrado de las Columnas </b> </h3>
# </body>

# %%
#   Definimos la nueva denominación que tendrán las columnas de interes
renamed_columns = {
                    "Cod_Loc":"cod_localidad", 
                    "IdProvincia":"id_provincia", 
                    "IdDepartamento":"id_departamento",
                    "categoria":"categoria", 
                    "provincia":"provincia", 
                    "localidad":"localidad", 
                    "nombre":"nombre", 
                    "direccion":"domicilio", 
                    "CP":"codigo_postal", 
                    "telefono":"numero_de_telefono", 
                    "Mail":"mail", 
                    "Web":"web"
                    }

# %%
#   Renombramos el dataframe
museum_edit_df.rename(columns = renamed_columns, inplace = True)
# Out:
# /tmp/ipykernel_37097/2237495416.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   museum_edit_df.rename(columns = renamed_columns, inplace = True)

# %%
#   Comprobamos que el dataframe haya sido actualizado con los cambios indicados
museum_edit_df.head()
# Out:
#    cod_localidad  id_provincia  id_departamento  \
# 0        6588100             6             6588
# 1        6077010             6             6077
# 2        6035010             6             6035
# 3        6035010             6             6035
# 4        6049020             6             6049
#
#                             categoria     provincia   localidad  \
# 0  Espacios de Exhibición Patrimonial  Buenos Aires  9 de Julio
# 1  Espacios de Exhibición Patrimonial  Buenos Aires   Arrecifes
# 2  Espacios de Exhibición Patrimonial  Buenos Aires  Avellaneda
# 3  Espacios de Exhibición Patrimonial  Buenos Aires  Avellaneda
# 4  Espacios de Exhibición Patrimonial  Buenos Aires        Azul
#
#                                               nombre  \
# 0     Archivo Y Museo Histórico Gral. Julio De Vedia
# 1             Museo Y Archivo Histórico De Arrecifes
# 2    Museo Histórico-Sacro  Hno. Rogelio Scortegagna
# 3   Museo Municipal De Artes Plásticas De Avellaneda
# ...

# %% [markdown]
# [<p style="font-family: rubik"> Índice </p> ](#id0)
#
# ---

# %% [markdown]
# <div id='id8' > </div>
#
# <head>
#      <meta http-equiv="Content-Type"content="text/html"charset="utf-8">
#      <title>VIAJES ALEGRES</title>
#      <link href="./css_estilos/estilo_01.css"rel="stylesheet"type="text/css">
# </head>
# <body>
#      <h2> <b> Fuente de Datos</b>: Salas de Cines </h2>
# </body>

# %%
#   Declaramos los parámetros para la carga del dataframe
path = "./dataset/sala_cine/2022-07/sala_cine-20-07-2022.csv"
sep = ","
cod = "utf-8"

cine_df = pd.read_csv(filepath_or_buffer = path, delimiter = sep, encoding = cod)

# %%
#   Visualizamos preliminarmente el dataframe
cine_df.head()
# Out:
#     Cod_Loc  IdProvincia  IdDepartamento  Observaciones      Categoría  \
# 0  10049030           10           10049            NaN  Salas de cine
# 1  10091150           10           10091            NaN  Salas de cine
# 2  22140060           22           22140            NaN  Salas de cine
# 3  26091020           26           26091            NaN  Salas de cine
# 4  18007010           18           18007            NaN  Salas de cine
#
#     Provincia  Departamento    Localidad                       Nombre  \
# 0   Catamarca       Capital    Catamarca                 Cinemacenter
# 1   Catamarca   Santa Maria  Santa María  Centro Cultural San Agustín
# 2       Chaco  San Fernando  Resistencia        Los Cines De La Costa
# 3      Chubut     Sarmiento    Sarmiento    Deborah Jones De Williams
# 4  Corrientes   Bella Vista  Bella Vista                     Fantasio
#
#                                Dirección  ... Información adicional  \
# ...

# %% [markdown]
# <head>
#      <meta http-equiv="Content-Type"content="text/html"charset="utf-8">
#      <title>VIAJES ALEGRES</title>
#      <link href="./css_estilos/estilo_01.css"rel="stylesheet"type="text/css">
# </head>
# <body>
#      <h3> <b> Identificación de los Tipos de Datos </b> </h3>
# </body>

# %%
#   Visualizamos las columnas del dataframe y sus tipos de datos
cine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Cod_Loc                329 non-null    int64
#  1   IdProvincia            329 non-null    int64
#  2   IdDepartamento         329 non-null    int64
#  3   Observaciones          0 non-null      float64
#  4   Categoría              329 non-null    object
#  5   Provincia              329 non-null    object
#  6   Departamento           329 non-null    object
#  7   Localidad              329 non-null    object
#  8   Nombre                 329 non-null    object
#  9   Dirección              329 non-null    object
#  10  Piso                   329 non-null    object
#  11  CP                     329 non-null    int64
#  12  cod_area               329 non-null    object
#  13  Teléfono               329 non-null    object
# ...

# %% [markdown]
# <head>
#      <meta http-equiv="Content-Type"content="text/html"charset="utf-8">
#      <title>VIAJES ALEGRES</title>
#      <link href="./css_estilos/estilo_01.css"rel="stylesheet"type="text/css">
# </head>
# <body>
#      <h3> <b> Selección de las Columnas de Interes </b> </h3>
# </body>

# %%
#   Definimos las columnas que deseamos conservar
columns = [ 
            "Cod_Loc", 
            "IdProvincia", 
            "IdDepartamento", 
            "Categoría", 
            "Provincia", 
            "Localidad", 
            "Nombre", 
            "Dirección", 
            "CP", 
            "Teléfono", 
            "Mail", 
            "Web"
            ]

# %%
#   Duplicamos el dataframe original conservando únicamente las columnas de interes
cine_edit_df = cine_df[columns]

# %% [markdown]
# <head>
#      <meta http-equiv="Content-Type"content="text/html"charset="utf-8">
#      <title>VIAJES ALEGRES</title>
#      <link href="./css_estilos/estilo_01.css"rel="stylesheet"type="text/css">
# </head>
# <body>
#      <h3> <b> Renombrado de las Columnas </b> </h3>
# </body>

# %%
#   Definimos la nueva denominación que tendrán las columnas de interes
renamed_columns = {
                    "Cod_Loc":"cod_localidad",
                    "IdProvincia":"id_provincia",
                    "IdDepartamento":"id_departamento",
                    "Categoría":"categoria",
                    "Provincia":"provincia",
                    "Localidad":"localidad",
                    "Nombre":"nombre",
                    "Dirección":"domicilio",
                    "CP":"codigo_postal",
                    "Teléfono":"numero_de_telefono",
                    "Mail":"mail",
                    "Web":"web"
                    }

# %%
#   Renombramos el dataframe
cine_edit_df.rename(columns = renamed_columns, inplace = True)
# Out:
# /tmp/ipykernel_37097/1090936705.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cine_edit_df.rename(columns = renamed_columns, inplace = True)

# %%
#   Comprobamos que el dataframe haya sido actualizado con los cambios indicados
cine_edit_df.head()
# Out:
#    cod_localidad  id_provincia  id_departamento      categoria   provincia  \
# 0       10049030            10            10049  Salas de cine   Catamarca
# 1       10091150            10            10091  Salas de cine   Catamarca
# 2       22140060            22            22140  Salas de cine       Chaco
# 3       26091020            26            26091  Salas de cine      Chubut
# 4       18007010            18            18007  Salas de cine  Corrientes
#
#      localidad                       nombre  \
# 0    Catamarca                 Cinemacenter
# 1  Santa María  Centro Cultural San Agustín
# 2  Resistencia        Los Cines De La Costa
# 3    Sarmiento    Deborah Jones De Williams
# 4  Bella Vista                     Fantasio
#
#                                domicilio  codigo_postal numero_de_telefono  \
# 0          Intendente Mamerto Medina 220           4700                s/d
# 1                         San Martin 173           4139             421511
# ...

# %% [markdown]
# [<p style="font-family: rubik"> Índice </p> ](#id0)
#
# ---

# %% [markdown]
# <div id='id9' > </div>
#
# <head>
#      <meta http-equiv="Content-Type"content="text/html"charset="utf-8">
#      <title>VIAJES ALEGRES</title>
#      <link href="./css_estilos/estilo_01.css"rel="stylesheet"type="text/css">
# </head>
# <body>
#      <h2> <b> Unión de los Dataframes </b> </h2>
# </body>

# %%
#   Agrupamos en un diccionario las fuentes de datos y sus respectivos dataframes
df_dict = {
            "bibliotecas_polulares": library_edit_df, 
            "museos": museum_edit_df, 
            "salas_cine": cine_edit_df
            }

# %%
#   Concatenamos en un único dataframe los datos recuperados de las fuentes indicadas
culture_df = pd.concat(df_dict, axis = 0, ignore_index=True)

# %%
#   Comprobamos que el dataframe haya sido creado correctamente
culture_df.head()
# Out:
#    cod_localidad  id_provincia  id_departamento              categoria  \
# 0       70049060            70            70049  Bibliotecas Populares
# 1        2000010             2             2000  Bibliotecas Populares
# 2        2000010             2             2000  Bibliotecas Populares
# 3        2000010             2             2000  Bibliotecas Populares
# 4        2000010             2             2000  Bibliotecas Populares
#
#                          provincia               localidad  \
# 0                         San Juan                   Rodeo
# 1  Ciudad Autónoma de Buenos Aires  Ciudad de Buenos Aires
# 2  Ciudad Autónoma de Buenos Aires  Ciudad de Buenos Aires
# 3  Ciudad Autónoma de Buenos Aires  Ciudad de Buenos Aires
# 4  Ciudad Autónoma de Buenos Aires  Ciudad de Buenos Aires
#
#                                         nombre             domicilio  \
# 0         Biblioteca Popular Juan P. Garramuno         Santo Domingo
# ...

# %% [markdown]
# [<p style="font-family: rubik"> Índice </p> ](#id0)
#
# ---

# %% [markdown]
# <div id='id10' > </div>
#
# <head>
#      <meta http-equiv="Content-Type"content="text/html"charset="utf-8">
#      <title>VIAJES ALEGRES</title>
#      <link href="./css_estilos/estilo_01.css"rel="stylesheet"type="text/css">
# </head>
# <body>
#      <h1> <b> Obtención de los Insights </b> <br> </h1>
# </body>

# %% [markdown]
# <head>
#      <meta http-equiv="Content-Type"content="text/html"charset="utf-8">
#      <title>VIAJES ALEGRES</title>
#      <link href="./css_estilos/estilo_01.css"rel="stylesheet"type="text/css">
# </head>
# <body>
#      <h2> <b> A partir de: </b> "culture_df" </h2>
# </body>

# %% [markdown]
# <head>
#      <meta http-equiv="Content-Type"content="text/html"charset="utf-8">
#      <title>VIAJES ALEGRES</title>
#      <link href="./css_estilos/estilo_01.css"rel="stylesheet"type="text/css">
# </head>
# <body>
#     <ul>
#         <li> <b> <p>
#         Cantidad de registros totales por categoría
#         </b>: </p> </li>
#     </ul>
# </body>

# %%
#   Agrupamos por categoría y contabilizamos los regístros
culture_df.groupby(["categoria"], as_index=False).size()
# Out:
#                             categoria  size
# 0               Bibliotecas Populares  2017
# 1  Espacios de Exhibición Patrimonial  1182
# 2                       Salas de cine   329

# %% [markdown]
# <head>
#      <meta http-equiv="Content-Type"content="text/html"charset="utf-8">
#      <title>VIAJES ALEGRES</title>
#      <link href="./css_estilos/estilo_01.css"rel="stylesheet"type="text/css">
# </head>
# <body>
#     <ul>
#         <li> <b> <p>
#         Cantidad de registros por provincia y categoría
#         </b>: </p> </li>
#     </ul>
# </body>

# %%
#   Agrupamos por categoría y provincia, luego contabilizamos los regístros
culture_df.groupby(["categoria", "provincia"], as_index=False).size()
# Out:
#                 categoria                        provincia  size
# 0   Bibliotecas Populares                     Buenos Aires   543
# 1   Bibliotecas Populares                        Catamarca    38
# 2   Bibliotecas Populares                            Chaco    70
# 3   Bibliotecas Populares                           Chubut    48
# 4   Bibliotecas Populares  Ciudad Autónoma de Buenos Aires    43
# ..                    ...                              ...   ...
# 68          Salas de cine                       Santa Cruz     5
# 69          Salas de cine                         Santa Fe    23
# 70          Salas de cine              Santiago del Estero     5
# 71          Salas de cine                 Tierra del Fuego     3
# 72          Salas de cine                          Tucumán     8
#
# [73 rows x 3 columns]

# %% [markdown]
# <head>
#      <meta http-equiv="Content-Type"content="text/html"charset="utf-8">
#      <title>VIAJES ALEGRES</title>
#      <link href="./css_estilos/estilo_01.css"rel="stylesheet"type="text/css">
# </head>
# <body>
#     <ul>
#         <li> <b> <p>
#         Cantidad de registros totales por fuente de datos
#         </b>: </p> </li>
#     </ul>
# </body>

# %%
#   Contabilizamos los elementos del dataframe y los segregamos por fuente de datos, a partir del diccionario de dataframes
lst = list()
for name, df in df_dict.items():
    lst.append({"source": name, "count":df.size})

# %%
#   Mostramos en un dataframe la segmentación resultante
pd.DataFrame(lst)
# Out:
#                   source  count
# 0  bibliotecas_polulares  24204
# 1                 museos  14184
# 2             salas_cine   3948

# %% [markdown]
# [<p style="font-family: rubik"> Índice </p> ](#id0)
#
# ---

# %% [markdown]
# <head>
#      <meta http-equiv="Content-Type"content="text/html"charset="utf-8">
#      <title>VIAJES ALEGRES</title>
#      <link href="./css_estilos/estilo_01.css"rel="stylesheet"type="text/css">
# </head>
# <body>
#      <h2> <b> A partir de: </b> "cine_df" </h2>
#      <p> Procesar la información para poder crear una tabla que contenga; </p>
# </body>

# %% [markdown]
# <head>
#      <meta http-equiv="Content-Type"content="text/html"charset="utf-8">
#      <title>VIAJES ALEGRES</title>
#      <link href="./css_estilos/estilo_01.css"rel="stylesheet"type="text/css">
# </head>
# <body>
#     <ul>
#         <li> <b> <p>
#         Provincia.
#         </b> </p> </li>
#         <li> <b> <p>
#         Cantidad de pantallas.
#         </b> </p> </li>
#         <li> <b> <p>
#         Cantidad de butacas.
#         </b> </p> </li>
#         <li> <b> <p>
#         Cantidad de espacios INCAA.
#         </b> </p> </li>
#     </ul>
# </body>

# %%
#   Agrupamos por categoría y contabilizamos el número de patallas, butacas y espacios INCAA
cine_df.groupby("Provincia", as_index=False).count()[["Provincia", "Pantallas", "Butacas", "espacio_INCAA"]]
# Out:
#                           Provincia  Pantallas  Butacas  espacio_INCAA
# 0                      Buenos Aires        106      106             20
# 1                         Catamarca          4        4              2
# 2                             Chaco          4        4              1
# 3                            Chubut          9        9              4
# 4   Ciudad Autónoma de Buenos Aires         35       35              3
# 5                        Corrientes          8        8              1
# 6                           Córdoba         35       35              2
# 7                        Entre Ríos         13       13              2
# 8                           Formosa          2        2              1
# 9                             Jujuy          4        4              2
# 10                         La Pampa          6        6              2
# 11                         La Rioja          5        5              1
# ...

# %% [markdown]
# [<p style="font-family: rubik"> Índice </p> ](#id0)
#
# ---
